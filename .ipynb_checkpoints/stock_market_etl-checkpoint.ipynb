# %%
import pandas as pd

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file1 = "Resources/fundamentals.csv"
fundamentals_data_df = pd.read_csv(csv_file1)
fundamentals_data_df.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %%
csv_file3 = "Resources/securities.csv"
securities_data_df = pd.read_csv(csv_file3)
securities_data_df.head()
# Out:
#   Ticker symbol             Security SEC filings             GICS Sector  \
# 0           MMM           3M Company     reports             Industrials
# 1           ABT  Abbott Laboratories     reports             Health Care
# 2          ABBV               AbbVie     reports             Health Care
# 3           ACN        Accenture plc     reports  Information Technology
# 4          ATVI  Activision Blizzard     reports  Information Technology
#
#                 GICS Sub Industry   Address of Headquarters Date first added  \
# 0        Industrial Conglomerates       St. Paul, Minnesota              NaN
# 1           Health Care Equipment   North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals   North Chicago, Illinois       2012-12-31
# 3  IT Consulting & Other Services           Dublin, Ireland       2011-07-06
# 4     Home Entertainment Software  Santa Monica, California       2015-08-31
#
#        CIK
# 0    66740
# 1     1800
# 2  1551152
# 3  1467373
# ...

# %%
securities_data_df.columns
# Out:
# Index(['Ticker symbol', 'Security', 'SEC filings', 'GICS Sector',
#        'GICS Sub Industry', 'Address of Headquarters', 'Date first added',
#        'CIK'],
#       dtype='object')

# %%
fundamentals_data_df.columns
# Out:
# Index(['Unnamed: 0', 'Ticker Symbol', 'Period Ending', 'Accounts Payable',
#        'Accounts Receivable', 'Add'l income/expense items', 'After Tax ROE',
#        'Capital Expenditures', 'Capital Surplus', 'Cash Ratio',
#        'Cash and Cash Equivalents', 'Changes in Inventories', 'Common Stocks',
#        'Cost of Revenue', 'Current Ratio', 'Deferred Asset Charges',
#        'Deferred Liability Charges', 'Depreciation',
#        'Earnings Before Interest and Tax', 'Earnings Before Tax',
#        'Effect of Exchange Rate',
#        'Equity Earnings/Loss Unconsolidated Subsidiary', 'Fixed Assets',
#        'Goodwill', 'Gross Margin', 'Gross Profit', 'Income Tax',
#        'Intangible Assets', 'Interest Expense', 'Inventory', 'Investments',
#        'Liabilities', 'Long-Term Debt', 'Long-Term Investments',
#        'Minority Interest', 'Misc. Stocks', 'Net Borrowings', 'Net Cash Flow',
#        'Net Cash Flow-Operating', 'Net Cash Flows-Financing',
# ...

# %%
dF = fundamentals_data_df[["Ticker Symbol", 
                           "Period Ending",                            
                           "Total Revenue", 
                           "Sales, General and Admin.", 
                           "Cost of Revenue",
                           "Research and Development",
                           "Earnings Before Interest and Tax",
                           "Operating Income",
                           "Net Income",   
                           "Earnings Per Share",
                           "Estimated Shares Outstanding",
                           "Total Assets",                            
                           "Total Liabilities",
                           "Total Equity" 
]]
dF
# Out:
#      Ticker Symbol Period Ending  Total Revenue  Sales, General and Admin.  \
# 0              AAL    2012-12-31   2.485500e+10               1.297700e+10
# 1              AAL    2013-12-31   2.674300e+10               1.291300e+10
# 2              AAL    2014-12-31   4.265000e+10               2.068600e+10
# 3              AAL    2015-12-31   4.099000e+10               2.127500e+10
# 4              AAP    2012-12-29   6.205003e+09               2.440721e+09
# ...            ...           ...            ...                        ...
# 1776          ZION    2015-12-31   2.210591e+09               1.591239e+09
# 1777           ZTS    2013-12-31   4.561000e+09               1.613000e+09
# 1778           ZTS    2014-12-31   4.785000e+09               1.643000e+09
# 1779           ZTS    2015-12-31   4.765000e+09               1.532000e+09
# 1780           ZTS    2016-12-31   4.888000e+09               1.364000e+09
#
#       Cost of Revenue  Research and Development  \
# ...

# %%
dS = securities_data_df[["Ticker symbol",
                         "Security", 
                         "GICS Sector",
                         "GICS Sub Industry"
                         ]]
dS
# Out:
#     Ticker symbol                Security             GICS Sector  \
# 0             MMM              3M Company             Industrials
# 1             ABT     Abbott Laboratories             Health Care
# 2            ABBV                  AbbVie             Health Care
# 3             ACN           Accenture plc  Information Technology
# 4            ATVI     Activision Blizzard  Information Technology
# ..            ...                     ...                     ...
# 500          YHOO              Yahoo Inc.  Information Technology
# 501           YUM         Yum! Brands Inc  Consumer Discretionary
# 502           ZBH  Zimmer Biomet Holdings             Health Care
# 503          ZION           Zions Bancorp              Financials
# 504           ZTS                  Zoetis             Health Care
#
#                   GICS Sub Industry
# 0          Industrial Conglomerates
# 1             Health Care Equipment
# 2                   Pharmaceuticals
# ...

# %%
merged_df = pd.merge(dF, dS, how='left', left_on='Ticker Symbol', right_on='Ticker symbol')
merged_df.head()
# Out:
#   Ticker Symbol Period Ending  Total Revenue  Sales, General and Admin.  \
# 0           AAL    2012-12-31   2.485500e+10               1.297700e+10
# 1           AAL    2013-12-31   2.674300e+10               1.291300e+10
# 2           AAL    2014-12-31   4.265000e+10               2.068600e+10
# 3           AAL    2015-12-31   4.099000e+10               2.127500e+10
# 4           AAP    2012-12-29   6.205003e+09               2.440721e+09
#
#    Cost of Revenue  Research and Development  \
# 0     1.049900e+10                       0.0
# 1     1.101900e+10                       0.0
# 2     1.562000e+10                       0.0
# 3     1.109600e+10                       0.0
# 4     3.106967e+09                       0.0
#
#    Earnings Before Interest and Tax  Operating Income    Net Income  \
# 0                     -1.813000e+09      1.480000e+08 -1.876000e+09
# 1                     -1.324000e+09      1.399000e+09 -1.834000e+09
# ...

# %%
merged_df.count()
# Out:
# Ticker Symbol                       1781
# Period Ending                       1781
# Total Revenue                       1781
# Sales, General and Admin.           1781
# Cost of Revenue                     1781
# Research and Development            1781
# Earnings Before Interest and Tax    1781
# Operating Income                    1781
# Net Income                          1781
# Earnings Per Share                  1562
# Estimated Shares Outstanding        1562
# Total Assets                        1781
# Total Liabilities                   1781
# Total Equity                        1781
# Ticker symbol                       1781
# Security                            1781
# GICS Sector                         1781
# GICS Sub Industry                   1781
# dtype: int64

# %%
new_df = merged_df.dropna(how='any')
new_df.count()
# Out:
# Ticker Symbol                       1562
# Period Ending                       1562
# Total Revenue                       1562
# Sales, General and Admin.           1562
# Cost of Revenue                     1562
# Research and Development            1562
# Earnings Before Interest and Tax    1562
# Operating Income                    1562
# Net Income                          1562
# Earnings Per Share                  1562
# Estimated Shares Outstanding        1562
# Total Assets                        1562
# Total Liabilities                   1562
# Total Equity                        1562
# Ticker symbol                       1562
# Security                            1562
# GICS Sector                         1562
# GICS Sub Industry                   1562
# dtype: int64

# %%
drop_df = new_df.drop(columns=['Ticker symbol'])
drop_df
# Out:
#      Ticker Symbol Period Ending  Total Revenue  Sales, General and Admin.  \
# 0              AAL    2012-12-31   2.485500e+10               1.297700e+10
# 1              AAL    2013-12-31   2.674300e+10               1.291300e+10
# 2              AAL    2014-12-31   4.265000e+10               2.068600e+10
# 3              AAL    2015-12-31   4.099000e+10               2.127500e+10
# 4              AAP    2012-12-29   6.205003e+09               2.440721e+09
# ...            ...           ...            ...                        ...
# 1775          ZION    2014-12-31   2.361631e+09               1.654369e+09
# 1776          ZION    2015-12-31   2.210591e+09               1.591239e+09
# 1777           ZTS    2013-12-31   4.561000e+09               1.613000e+09
# 1778           ZTS    2014-12-31   4.785000e+09               1.643000e+09
# 1779           ZTS    2015-12-31   4.765000e+09               1.532000e+09
#
#       Cost of Revenue  Research and Development  \
# ...

# %%
drop_df['Ticker Symbol'].nunique()
# Out:
# 432

# %%
# Connect to local database
from sqlalchemy import create_engine
rds_connection_string = "<insert user name>:<insert password>@localhost:5432/nyse_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base
from sqlalchemy import Column, Integer, String, Float, Date

# %%
class  (Base):
    __tablename__ = 'table_name'
    id = Column(Integer, primary_key=True)
    column2_name = Column(String)
    column3_name = Column(String)
    column4_name = Column(Integer)
    column5_name = Column(Date)

# %% [markdown]
# ### Create new data with select columns
